# %% [markdown]
# Ipython notebooks allows for commands using the % symbol.

# %%
# %pwd
# Out:
# 'C:\\Users\\johnm\\Documents\\p4da'

# %% [markdown]
# One can also get information about an object using ?

# %%
var = [1,2,3]


def add_numbers(a,b):
    """
    Add two numbers together.
    """
    return a+b

# %%
var?
# Out:
# Type:        list
# String form: [1, 2, 3]
# Length:      3
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
add_numbers?
# Out:
# Signature: add_numbers(a, b)
# Docstring: Add two numbers together.
# File:      c:\users\johnm\appdata\local\temp\ipykernel_26432\2701228638.py
# Type:      function
